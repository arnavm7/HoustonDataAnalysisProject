# %% [markdown]
# Author: Arnav Mangal, Notebook Created: 01/09/2021.
# This notebook will be used for the IBM Coursera Applied Data Science Capstone Project.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
